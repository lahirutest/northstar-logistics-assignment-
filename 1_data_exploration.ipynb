# %%
# ============================================================
# NORTHSTAR DATA EXPLORATION NOTEBOOK
# FILE: 1_data_exploration.ipynb
# ============================================================

# ============================================================
# STEP 1 — IMPORT LIBRARIES
# ============================================================

import pandas as pd
import numpy as np
import os
import zipfile

# ============================================================
# STEP 2 — CHECK CURRENT CONTENTS
# ============================================================

print("CONTENT DIRECTORY:")
print(os.listdir('/content'))

# ============================================================
# STEP 3 — EXTRACT ZIP FILE
# ============================================================

# Make sure northstar_dataset.zip is uploaded first

zip_path = "/content/northstar_dataset.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/data")

print("\nDATASET EXTRACTED SUCCESSFULLY!")

# ============================================================
# STEP 4 — CHECK EXTRACTED FOLDERS
# ============================================================

print("\nFILES INSIDE /content/data/")
print(os.listdir('/content/data'))

print("\nFILES INSIDE /content/data/northstar_dataset/")
print(os.listdir('/content/data/northstar_dataset'))

# ============================================================
# STEP 5 — LOAD ALL DATASETS
# ============================================================

customers = pd.read_csv('/content/data/northstar_dataset/customers.csv')
orders = pd.read_csv('/content/data/northstar_dataset/orders.csv')
deliveries = pd.read_csv('/content/data/northstar_dataset/deliveries.csv')
drivers = pd.read_csv('/content/data/northstar_dataset/drivers.csv')
vehicles = pd.read_csv('/content/data/northstar_dataset/vehicles.csv')
complaints = pd.read_csv('/content/data/northstar_dataset/complaints.csv')
incidents = pd.read_csv('/content/data/northstar_dataset/incidents.csv')
hubs = pd.read_csv('/content/data/northstar_dataset/hubs.csv')
app_events = pd.read_csv('/content/data/northstar_dataset/app_events.csv')

print("\nALL DATASETS LOADED SUCCESSFULLY!")

# ============================================================
# STEP 6 — LOAD DATA DICTIONARY
# ============================================================

dictionary = pd.read_csv('/content/data/northstar_dataset/data_dictionary.csv')

print("\nDATA DICTIONARY")
print(dictionary.head(20))

# ============================================================
# STEP 7 — CHECK DATASET SHAPES
# ============================================================

print("\n================ DATASET SHAPES ================\n")

print("Customers:", customers.shape)
print("Orders:", orders.shape)
print("Deliveries:", deliveries.shape)
print("Drivers:", drivers.shape)
print("Vehicles:", vehicles.shape)
print("Complaints:", complaints.shape)
print("Incidents:", incidents.shape)
print("Hubs:", hubs.shape)
print("App Events:", app_events.shape)

# ============================================================
# STEP 8 — DISPLAY FIRST 5 ROWS
# ============================================================

print("\n================ CUSTOMERS HEAD ================\n")
print(customers.head())

print("\n================ ORDERS HEAD ================\n")
print(orders.head())

print("\n================ DELIVERIES HEAD ================\n")
print(deliveries.head())

print("\n================ DRIVERS HEAD ================\n")
print(drivers.head())

print("\n================ VEHICLES HEAD ================\n")
print(vehicles.head())

print("\n================ COMPLAINTS HEAD ================\n")
print(complaints.head())

print("\n================ INCIDENTS HEAD ================\n")
print(incidents.head())

print("\n================ HUBS HEAD ================\n")
print(hubs.head())

print("\n================ APP EVENTS HEAD ================\n")
print(app_events.head())

# ============================================================
# STEP 9 — DATASET INFORMATION
# ============================================================

print("\n================ CUSTOMERS INFO ================\n")
customers.info()

print("\n================ ORDERS INFO ================\n")
orders.info()

print("\n================ DELIVERIES INFO ================\n")
deliveries.info()

print("\n================ DRIVERS INFO ================\n")
drivers.info()

print("\n================ VEHICLES INFO ================\n")
vehicles.info()

print("\n================ COMPLAINTS INFO ================\n")
complaints.info()

print("\n================ INCIDENTS INFO ================\n")
incidents.info()

print("\n================ HUBS INFO ================\n")
hubs.info()

print("\n================ APP EVENTS INFO ================\n")
app_events.info()

# ============================================================
# STEP 10 — DESCRIPTIVE STATISTICS
# ============================================================

print("\n================ CUSTOMERS DESCRIPTION ================\n")
print(customers.describe())

print("\n================ ORDERS DESCRIPTION ================\n")
print(orders.describe())

print("\n================ DELIVERIES DESCRIPTION ================\n")
print(deliveries.describe())

print("\n================ DRIVERS DESCRIPTION ================\n")
print(drivers.describe())

print("\n================ VEHICLES DESCRIPTION ================\n")
print(vehicles.describe())

print("\n================ COMPLAINTS DESCRIPTION ================\n")
print(complaints.describe())

print("\n================ INCIDENTS DESCRIPTION ================\n")
print(incidents.describe())

print("\n================ HUBS DESCRIPTION ================\n")
print(hubs.describe())

print("\n================ APP EVENTS DESCRIPTION ================\n")
print(app_events.describe())

# ============================================================
# STEP 11 — CHECK MISSING VALUES
# ============================================================

print("\n================ CUSTOMERS MISSING VALUES ================\n")
print(customers.isnull().sum())

print("\n================ ORDERS MISSING VALUES ================\n")
print(orders.isnull().sum())

print("\n================ DELIVERIES MISSING VALUES ================\n")
print(deliveries.isnull().sum())

print("\n================ DRIVERS MISSING VALUES ================\n")
print(drivers.isnull().sum())

print("\n================ VEHICLES MISSING VALUES ================\n")
print(vehicles.isnull().sum())

print("\n================ COMPLAINTS MISSING VALUES ================\n")
print(complaints.isnull().sum())

print("\n================ INCIDENTS MISSING VALUES ================\n")
print(incidents.isnull().sum())

print("\n================ HUBS MISSING VALUES ================\n")
print(hubs.isnull().sum())

print("\n================ APP EVENTS MISSING VALUES ================\n")
print(app_events.isnull().sum())

# ============================================================
# STEP 12 — DISPLAY COLUMN NAMES
# ============================================================

print("\n================ CUSTOMERS COLUMNS ================\n")
print(customers.columns)

print("\n================ ORDERS COLUMNS ================\n")
print(orders.columns)

print("\n================ DELIVERIES COLUMNS ================\n")
print(deliveries.columns)

print("\n================ DRIVERS COLUMNS ================\n")
print(drivers.columns)

print("\n================ VEHICLES COLUMNS ================\n")
print(vehicles.columns)

print("\n================ COMPLAINTS COLUMNS ================\n")
print(complaints.columns)

print("\n================ INCIDENTS COLUMNS ================\n")
print(incidents.columns)

print("\n================ HUBS COLUMNS ================\n")
print(hubs.columns)

print("\n================ APP EVENTS COLUMNS ================\n")
print(app_events.columns)

# ============================================================
# STEP 13 — CHECK DUPLICATES
# ============================================================

print("\n================ DUPLICATE ROWS ================\n")

print("Customers:", customers.duplicated().sum())
print("Orders:", orders.duplicated().sum())
print("Deliveries:", deliveries.duplicated().sum())
print("Drivers:", drivers.duplicated().sum())
print("Vehicles:", vehicles.duplicated().sum())
print("Complaints:", complaints.duplicated().sum())
print("Incidents:", incidents.duplicated().sum())
print("Hubs:", hubs.duplicated().sum())
print("App Events:", app_events.duplicated().sum())

# ============================================================
# STEP 14 — UNIQUE VALUES FOR IMPORTANT FIELDS
# ============================================================

print("\n================ DELIVERY STATUS VALUES ================\n")
print(deliveries['delivery_status'].unique())

print("\n================ CUSTOMER TYPES ================\n")
print(customers['customer_type'].unique())

print("\n================ ACCOUNT STATUS ================\n")
print(customers['account_status'].unique())

print("\n================ VEHICLE TYPES ================\n")
print(vehicles['vehicle_type'].unique())

print("\n================ INCIDENT TYPES ================\n")
print(incidents['incident_type'].unique())

print("\n================ COMPLAINT TYPES ================\n")
print(complaints['complaint_type'].unique())

# ============================================================
# STEP 15 — FINAL SUMMARY
# ============================================================

print("""

============================================================
DATA EXPLORATION COMPLETE
============================================================

NEXT NOTEBOOK:
2_sql_r_analysis.ipynb

NEXT TASKS:
1. Identify table relationships
2. Identify business problems
3. Build SQL joins and aggregations
4. Begin analytical investigation

============================================================

""")
# Out:
# CONTENT DIRECTORY:
# ['.config', 'northstar_dataset.zip', 'sample_data']
#
# DATASET EXTRACTED SUCCESSFULLY!
#
# FILES INSIDE /content/data/
# ['northstar_dataset']
#
# FILES INSIDE /content/data/northstar_dataset/
# ['incidents.csv', 'deliveries.csv', 'customers.csv', 'data_dictionary.csv', 'app_events.csv', 'orders.csv', 'drivers.csv', 'complaints.csv', 'README.txt', 'hubs.csv', 'vehicles.csv']
#
# ALL DATASETS LOADED SUCCESSFULLY!
#
# DATA DICTIONARY
#         file_name  record_count  \
# 0        hubs.csv             8
# 1   customers.csv           650
# 2     drivers.csv           170
# 3    vehicles.csv           120
# 4      orders.csv          1250
# 5  deliveries.csv           950
# 6   incidents.csv           280
# 7  complaints.csv           320
# 8  app_events.csv           640
#
#                                          description
# 0                Operational hubs and control points
# 1  Customer master data with engagement and loyal...
# ...
